# %% [markdown]
# ## Потребление алкоголя студентами

# %% [markdown]
# Набор данных представляет собой результаты опроса 395 студентов средней школы, изучающих математику. Содержит социальную, гендерную и учебную информацию об учениках.

# %% [markdown]
# Атрибуты:

# %% [markdown]
# 1.	school -  школа ('GP' - Gabriel Pereira или 'MS' - Mousinho da Silveira)
# 2.	sex - пол ('F' - женщина или 'M' - мужчина)
# 3.	age - возраст студента (от 15 до 22)
# 4.	address - адрес студента  ('U' - городской или 'R' - сельский)
# 5.	famsize - количество членов семьи ('LE3' - 3 или меньше или 'GT3' - больше трех)
# 6.	Pstatus - статус сожительства родителей ('T' - живут вместе или 'A' - раздельно)
# 7.	Medu - образование матери (0 - нет, 1 - начальное образование (4 класса), 2 - от 5 до 9 классов, 3 - среднее образование или 4 - высшее образование)
# 8.	Fedu - образование отца (0 - нет, 1 - начальное образование (4 класса), 2 - от 5 до 9 классов, 3 - среднее образование или 4 - высшее образование)
# 9.	Mjob - работа матери ('teacher', 'health', 'services', 'at_home' или 'other')
# 10.	Fjob - работа отца ('teacher', 'health', 'services', 'at_home' или 'other')
# 11.	reason - причина выбора этой школы ('home’ – близко к дому, 'reputation' – репутация школы, 'course' или  'other')
# 12.	guardian - опекун студента ('mother', 'father' or 'other')
# 13.	traveltime - время пути до школы (1 - <2 часов, 2 – от 2 до 5 часов, 3 – от 5 до 10 часов или 4 - >10 часов)
# 14.	studytime - количество учебы в неделю (1 - <2 часов, 2 – от 2 до 5 часов, 3 – от 5 до 10 часов или 4 - >10 часов)
# 15.	failures - количество прошлых неудач в классе (n если 1<=n<3, иначе 4)
# 16.	schoolsup – дополнительная образовательная поддержка (yes или no)
# 17.	famsup – семейная образовательная поддержка (yes или no)
# 18.	paid – дополнительные оплачиваемые уроки по математике (yes или no)
# 19.	activities – внеклассные занятия (yes или no)
# 20.	nursery – посещал ли студент детский сад (yes или no)
# 21.	higher – хочет ли студент получить высшее образование (yes или no)
# 22.	internet – есть ли доступ к интернету дома (yes или no)
# 23.	romantic – состоит ли студент в отношениях (yes или no)
# 24.	famrel – отношения в семье (от 1 – очень плохие до 5 – отличные)
# 25.	freetime - свободное время после школы (от 1 – очень мало до 5 – очень много)
# 26.	goout – прогулки с друзьями (от 1 – очень мало до 5 – очень много)
# 27.	Dalc – потребление алкоголя в течение рабочего дня (от 1 – очень мало до 5 – очень много)
# 28.	Walc - потребление алкоголя в выходные (от 1 – очень мало до 5 – очень много)
# 29.	health – текущее состояние здоровья (от 1 – очень плохое до 5 – очень хорошее)
# 30.	absences – количество прогулов (от 0 до 93)
# 31.	G1 – оценка по математике за первый период (от 0 до 20)
# 32.	G1 - оценка по математике за второй период (от 0 до 20)
# 33.	G3 - итоговая оценка по математике (от 0 до 20)
# Задача состоит в том, чтобы определить, хочет ли студент получать высшее образование (значение признака 'highter')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Считываем данные из файла

# %%
url = 'https://raw.githubusercontent.com/mitrokhina/ML_Homeworks/master/student-mat.csv'
data = pd.read_csv(url, sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Выведем все данные:

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
print(data.shape)
# Out:
# (395, 33)

# %% [markdown]
# В таблице 395 строк (студенты) и 33 столбца (атрибуты)

# %% [markdown]
# Выведем названия всех столбцов

# %%
print(data.columns)
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# Посмотрим общую информацию по всем данным:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %% [markdown]
# Видим, что в таблице у нас имеются данные типа int64 и object

# %% [markdown]
# Выведем первые 5 строк таблицы

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Последние 5 строк таблицы:

# %%
data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390 ...      5        5      4     4     5      4       11   9   9   9
# 391 ...      2        4      5     3     4      2        3  14  16  16
# 392 ...      5        5      3     3     3      3        3  10   8   7
# 393 ...      4        4      1     3     4      5        0  11  12  10
# 394 ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# Посмотрим основные статистические характеристики для количественных данных

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data.describe(include = ['object'])
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     395     395     395    395    395     395      395
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     307     281     354    141    217     145      273
#
#        schoolsup famsup paid activities nursery higher internet romantic
# count        395    395  395        395     395    395      395      395
# unique         2      2    2          2       2      2        2        2
# top           no    yes   no        yes     yes    yes      yes       no
# freq         344    242  214        201     314    375      329      263

# %% [markdown]
# А также выведем информацию по всем признакам

# %%
data.describe(include = 'all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob     ...          famrel    freetime  \
# count   395.000000    395    395     ...      395.000000  395.000000
# ...

# %% [markdown]
# Посмотрим данные о свободном времени всех студентов

# %%
data['freetime']
# Out:
# 0      3
# 1      3
# 2      3
# 3      2
# 4      3
# 5      4
# 6      4
# 7      1
# 8      2
# 9      5
# 10     3
# 11     2
# 12     3
# 13     4
# 14     5
# 15     4
# 16     2
# 17     3
# 18     5
# 19     1
# 20     4
# 21     4
# 22     5
# 23     4
# 24     3
# 25     2
# 26     2
# 27     2
# 28     3
# 29     4
#       ..
# 365    3
# 366    2
# 367    2
# 368    2
# 369    2
# 370    2
# 371    3
# 372    4
# 373    5
# 374    4
# 375    3
# 376    4
# 377    4
# 378    1
# 379    5
# 380    2
# 381    4
# 382    4
# 383    3
# 384    4
# 385    3
# 386    4
# 387    4
# 388    3
# 389    1
# 390    5
# 391    4
# 392    5
# 393    4
# 394    2
# Name: freetime, Length: 395, dtype: int64

# %% [markdown]
# Узнаем возраст четвертого в списке студента

# %%
data.at[4, 'age']
# Out:
# 16

# %% [markdown]
# Выведем данные о первых пяти студентах - пол, возраст и имеется ли у них доступ к интернету из дома

# %%
data[['sex', 'age', 'internet']].head()
# Out:
#   sex  age internet
# 0   F   18       no
# 1   F   17      yes
# 2   F   15      yes
# 3   F   15      yes
# 4   F   16       no

# %%
from pandas.tools.plotting import scatter_matrix

# %%
numerical_columns = [c for c in data.columns if data[c].dtype.name != 'object']

# %%
scatter_matrix(data[numerical_columns], alpha = .2, figsize = (10, 10))
pass
# Out:
# C:\Anaconda1\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Посмотрим таблицу корреляций

# %%
data.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %% [markdown]
# Заметим, что коэффициент корреляции между признаками 'Dalc' (потребление алкоголя в течение рабочего дня) и 'Walc' (потребление алкоголя в выходные) равен 0.647544. Из этого можно сделать вывод, что есть зависимость между потреблением алкоголя студентами в будние и выходные дни. А также коэффициенты корреляции между оценками по математике за первый, второй периоды и итоговой оценкой более 0.8, что отражает вполне естественную зависимость.

# %%
(data['traveltime'] > 1).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: traveltime, dtype: bool

# %% [markdown]
# Видим, что путь до школы у студентов с номерами от 1 до 4 занимает менее 2х часов

# %%
data.at[0, 'traveltime']
# Out:
# 2

# %% [markdown]
# У студента под номером 0 путь до школы занимает от 2х до 5 часов

# %% [markdown]
# Посмотрим, посещали ли студенты детский сад

# %%
data['nursery'] == 'yes'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 365     True
# 366     True
# 367     True
# 368     True
# 369    False
# 370     True
# 371     True
# 372     True
# 373     True
# 374     True
# 375     True
# 376    False
# 377     True
# 378     True
# 379    False
# 380    False
# 381    False
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# 387    False
# 388     True
# 389     True
# 390     True
# 391    False
# 392    False
# 393    False
# 394     True
# Name: nursery, Length: 395, dtype: bool

# %% [markdown]
# Отобразим уникальные значения признака traveltime (время пути до школы)

# %%
data['traveltime'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %% [markdown]
# А также уникальные значения категориального признака 'Mjob' (работа матери)

# %%
data['Mjob'].unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %% [markdown]
# Нарисуем график зависимости количества прогулок с друзьями от возраста опрошенных

# %%
plt.plot(data['age'], data['goout'], 'o', alpha = 0.05)
plt.xlabel('age')
plt.ylabel('goout')
plt.title('Age vs Going out with friends')
pass

# %% [markdown]
# ## Готовим данные

# %%
data['age'].dtype.name
# Out:
# 'int64'

# %%
data['famsize'].dtype.name
# Out:
# 'object'

# %% [markdown]
# Отобразим категориальные и количественные признаки

# %%
categorical_columns = [i for i in data.columns if data[i].dtype.name == 'object']
print(categorical_columns)   
numerical_columns   = [i for i in data.columns if data[i].dtype.name != 'object']
print(numerical_columns)
# Out:
# ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
# ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %% [markdown]
# Для каждого категориального признака выведем все возможные значения

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# school ['GP' 'MS']
# sex ['F' 'M']
# address ['U' 'R']
# famsize ['GT3' 'LE3']
# Pstatus ['A' 'T']
# Mjob ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob ['teacher' 'other' 'services' 'health' 'at_home']
# reason ['course' 'other' 'home' 'reputation']
# guardian ['mother' 'father' 'other']
# schoolsup ['yes' 'no']
# famsup ['no' 'yes']
# paid ['no' 'yes']
# activities ['no' 'yes']
# nursery ['yes' 'no']
# higher ['yes' 'no']
# internet ['no' 'yes']
# romantic ['no' 'yes']

# %% [markdown]
# ## Пропущенные значения

# %% [markdown]
# Средние значения по всем количественным признакам:

# %%
data.median(axis = 0)
# Out:
# age           17.0
# Medu           3.0
# Fedu           2.0
# traveltime     1.0
# studytime      2.0
# failures       0.0
# famrel         4.0
# freetime       3.0
# goout          3.0
# Dalc           1.0
# Walc           2.0
# health         4.0
# absences       4.0
# G1            11.0
# G2            11.0
# G3            11.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# age           395
# Medu          395
# Fedu          395
# traveltime    395
# studytime     395
# failures      395
# famrel        395
# freetime      395
# goout         395
# Dalc          395
# Walc          395
# health        395
# absences      395
# G1            395
# G2            395
# G3            395
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# school        395
# sex           395
# address       395
# famsize       395
# Pstatus       395
# Mjob          395
# Fjob          395
# reason        395
# guardian      395
# schoolsup     395
# famsup        395
# paid          395
# activities    395
# nursery       395
# higher        395
# internet      395
# romantic      395
# dtype: int64

# %% [markdown]
# Пропущенных значений нет

# %% [markdown]
# ##  Векторизация

# %% [markdown]
# Выведем бинарные и небинарные категориальные признаки

# %%
data_describe = data.describe(include = [object])
binary_columns = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['school', 'sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'] ['Mjob', 'Fjob', 'reason', 'guardian']

# %% [markdown]
# Векторизуем бинарные признаки

# %%
data['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data.at[data['sex'] == 'M', 'sex'] = 0
data.at[data['sex'] == 'F', 'sex'] = 1
data['sex'].describe()
# Out:
# count     395
# unique      2
# top         1
# freq      208
# Name: sex, dtype: int64

# %%
data['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data.at[data['school'] == 'GP', 'school'] = 0
data.at[data['school'] == 'MS', 'school'] = 1
data['school'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      349
# Name: school, dtype: int64

# %%
data['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
data.at[data['address'] == 'U', 'address'] = 0
data.at[data['address'] == 'R', 'address'] = 1
data['address'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      307
# Name: address, dtype: int64

# %%
data['famsize'].unique()
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
data.at[data['famsize'] == 'GT3', 'famsize'] = 0
data.at[data['famsize'] == 'LE3', 'famsize'] = 1
data['famsize'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      281
# Name: famsize, dtype: int64

# %%
data['Pstatus'].unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
data.at[data['Pstatus'] == 'A', 'Pstatus'] = 0
data.at[data['Pstatus'] == 'T', 'Pstatus'] = 1
data['Pstatus'].describe()
# Out:
# count     395
# unique      2
# top         1
# freq      354
# Name: Pstatus, dtype: int64

# %%
data['schoolsup'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data.at[data['schoolsup'] == 'yes', 'schoolsup'] = 0
data.at[data['schoolsup'] == 'no', 'schoolsup'] = 1
data['schoolsup'].describe()
# Out:
# count     395
# unique      2
# top         1
# freq      344
# Name: schoolsup, dtype: int64

# %%
data['famsup'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.at[data['famsup'] == 'yes', 'famsup'] = 0
data.at[data['famsup'] == 'no', 'famsup'] = 1
data['famsup'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      242
# Name: famsup, dtype: int64

# %%
data['paid'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.at[data['paid'] == 'yes', 'paid'] = 0
data.at[data['paid'] == 'no', 'paid'] = 1
data['paid'].describe()
# Out:
# count     395
# unique      2
# top         1
# freq      214
# Name: paid, dtype: int64

# %%
data['activities'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.at[data['activities'] == 'yes', 'activities'] = 0
data.at[data['activities'] == 'no', 'activities'] = 1
data['activities'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      201
# Name: activities, dtype: int64

# %%
data['nursery'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data.at[data['nursery'] == 'yes', 'nursery'] = 0
data.at[data['nursery'] == 'no', 'nursery'] = 1
data['nursery'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      314
# Name: nursery, dtype: int64

# %%
data['internet'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.at[data['internet'] == 'yes', 'internet'] = 0
data.at[data['internet'] == 'no', 'internet'] = 1
data['internet'].describe()
# Out:
# count     395
# unique      2
# top         0
# freq      329
# Name: internet, dtype: int64

# %%
data['romantic'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.at[data['romantic'] == 'yes', 'romantic'] = 0
data.at[data['romantic'] == 'no', 'romantic'] = 1
data['romantic'].describe()
# Out:
# count     395
# unique      2
# top         1
# freq      263
# Name: romantic, dtype: int64

# %% [markdown]
# Векторизуем небинарные признаки 'Mjob', 'Fjob', 'reason', 'guardian'

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other'],
#       dtype='object')

# %% [markdown]
# ## Нормализация количественных признаков

# %% [markdown]
# Выведем количественные признаки

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Нормализованные количественные признаки:

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#                 age          Medu          Fedu    traveltime     studytime  \
# count  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02
# mean   3.714609e-15  4.497106e-17  1.911270e-17  2.234500e-16 -3.563956e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.329268e+00 -2.511445e+00 -2.317145e+00 -6.424347e-01 -1.233786e+00
# 25%   -5.455950e-01 -6.845191e-01 -4.792490e-01 -6.424347e-01 -1.233786e+00
# 50%    2.380778e-01  2.289439e-01 -4.792490e-01 -6.424347e-01 -4.223229e-02
# 75%    1.021751e+00  1.142407e+00  4.396993e-01  7.912473e-01 -4.223229e-02
# max    4.156442e+00  1.142407e+00  1.358648e+00  3.658611e+00  2.340875e+00
#
#            failures        famrel      freetime         goout          Dalc  \
# count  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02
# mean  -2.254174e-16 -1.180490e-16  5.677596e-17 -3.618765e-18 -2.979333e-16
# ...

# %% [markdown]
# ## Объединение в одну таблицу

# %% [markdown]
# Новая таблица будет состоять из нормализованных количественных столбцов и векторизованных категориальных

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
data.describe()
# Out:
# (395, 46)
#                 age          Medu          Fedu    traveltime     studytime  \
# count  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02
# mean   3.714609e-15  4.497106e-17  1.911270e-17  2.234500e-16 -3.563956e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.329268e+00 -2.511445e+00 -2.317145e+00 -6.424347e-01 -1.233786e+00
# 25%   -5.455950e-01 -6.845191e-01 -4.792490e-01 -6.424347e-01 -1.233786e+00
# 50%    2.380778e-01  2.289439e-01 -4.792490e-01 -6.424347e-01 -4.223229e-02
# 75%    1.021751e+00  1.142407e+00  4.396993e-01  7.912473e-01 -4.223229e-02
# max    4.156442e+00  1.142407e+00  1.358648e+00  3.658611e+00  2.340875e+00
#
#            failures        famrel      freetime         goout          Dalc  \
# count  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02  3.950000e+02
# mean  -2.254174e-16 -1.180490e-16  5.677596e-17 -3.618765e-18 -2.979333e-16
# ...

# %% [markdown]
# ## X и y

# %%
X = data.drop(('higher'), axis = 1) #выбрасываем столбец'higher'
y = data['higher']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'school', 'sex', 'address',
#        'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'internet', 'romantic'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (395, 45)
# (395,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 12)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 276 119

# %%
276+119
# Out:
# 395

# %% [markdown]
# ## kNN

# %% [markdown]
#  Выберем количество соседей k = 5

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# Используя метод predict(X), вычислим значение ошибки

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0398550724638 0.0756302521008

# %% [markdown]
# Посчитаем значение ошибки другим способом

# %%
err_test = 1 - knn.score(X_test, y_test)
err_test
# Out:
# 0.075630252100840289

# %% [markdown]
# С помощью метода confusion_matrix вычислим матрицу, (i,j) элемент которой равен числу объектов из группы i, но по предсказанию находящихся в группе j

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[  0   9]
#  [  0 110]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# ## Подбор параметров

# %% [markdown]
# Найдем значение параметра k, при котором величина ошибки минимальна

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.0398550724638 5

# %% [markdown]
# Получили, что параметр k = 5 был верно выбран изначально

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0398550724638 0.0756302521008
